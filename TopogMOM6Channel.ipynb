# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
import xarray as xr
import cmocean as cm

# %% [markdown]
# Load topography from the ACCESS-OM2 input directories.

# %%
TopogFile='/g/data/ik11/inputs/access-om2/input_ff9890e2/mom_01deg/topog.nc'
da = xr.open_dataset(TopogFile).depth
da

# %% [markdown]
# Note that `da` has no coordinates, so we need to check with an output file that we are selecting the latitude range that we want - roughly 70S to 35S.

# %%
GridFile = '/home/157/amh157/cosima/access-om2-01/01deg_jra55v13_ryf9091/output381/ocean/ocean_grid.nc'
yt = xr.open_dataset(GridFile).yt_ocean
print(yt.isel(yt_ocean=263).values)
print(yt.isel(yt_ocean=871).values)
# Out:
# -69.99968147628742
# -34.95512575180556

# %%
ChannelTopog = da.isel(yy=slice(263,871))

# %%
plt.figure(figsize=(15,4))
ChannelTopog.plot()

# %% [markdown]
# Is this a reasonable domain to work with??
