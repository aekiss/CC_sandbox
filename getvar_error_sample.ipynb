# %%
# %matplotlib inline

import cosima_cookbook as cc
import logging
logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)

# %%
db = '/g/data3/hh5/tmp/cosima/database/access-om2-01.db'
variable = 'temp_surface_ave'
expt = 'access-om2-01/01deg_jra55v13_ryf8485_spinup6'

# %%
## For this one, change kernel to 19.04 and watch it fail ...
darray = cc.querying.getvar(expt, variable, db, n=50)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-f7dffa81455c> in <module>
#       1 ## For this one, change kernel to 19.04 and watch it fail ...
# ----> 2 darray = cc.querying.getvar(expt, variable, db, n=50)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-19.04/lib/python3.6/site-packages/cosima_cookbook/querying.py in getvar(expt, variable, db, ncfile, n, start_time, end_time, chunks, time_units, offset, decode_times, check_present)
#      73     # chunking -- use first row/file
#      74     try:
# ---> 75         file_chunks = dict(zip(eval(ncfiles[0][1]), eval(ncfiles[0][2])))
#      76         # apply caller overrides
#      77         if chunks is not None:
#
# IndexError: list index out of range

# %%
## This uses the old database structure ... needs kernel 19.01 or earlier.
darray = cc.get_nc_variable(expt, 'ocean_scalar.nc', variable,
                          time_units='days since 1900-01-01',n=50)
darray.plot()
# Out:
# Using database sqlite:////g/data3/hh5/tmp/cosima/cosima-cookbook/cosima-cookbook.db
